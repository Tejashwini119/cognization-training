# %%
file = open("demo.txt","r")
content = file.read()
print(content)
file.close()

# %%
file=open("awdc.txt","r")
Content=file.read()
print(Content)
file.close()
# Out:
# hello welcome to python class
