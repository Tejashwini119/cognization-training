# %%
 try:
     num=int(input("enter the number"))
     print(10/Number)
 except NumberDIVISIONError
    print("cannont divide by number")
# Out:
#   Cell In[4], line 4
#     except NumberDIVISIONError
#                               ^
# SyntaxError: expected ':'
